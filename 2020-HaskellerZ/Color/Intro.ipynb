-- %%
import Demo
import Data.Massiv.Array as A
import Data.Massiv.Array.IO as A

-- %%
import Graphics.Color.Model as C

c = C.ColorRGB 0 127 255 :: Color RGB Word8
print c
showColorRGB c
-- Out:
-- <RGB:(  0,127,255)>

-- %%
toFloat <$> c
toDouble <$> c
-- Out:
-- <RGB:( 0.000000, 0.498039, 1.000000)>
-- <RGB:( 0.000000000000, 0.498039215686, 1.000000000000)>

-- %%
toWord16 <$> c
toWord32 <$> c
toWord64 <$> c
-- Out:
-- <RGB:(    0,32639,65535)>
-- <RGB:(         0,2139062143,4294967295)>
-- <RGB:(                   0, 9187201950435737471,18446744073709551615)>

-- %%
:t ColorRGB
toWord64 <$> (ColorRGB         1.0 0.2 0.0001 :: Color RGB Double)

:set -XTypeApplications
toWord64 <$> (ColorRGB @Double 1.0 0.2 0.0001)
-- Out:
-- ColorRGB :: forall e. e -> e -> e -> Color RGB e
-- <RGB:(                   0, 3689348814741910528,    1844674407370955)>
-- <RGB:(                   0, 3689348814741910528,    1844674407370955)>

-- %%
c = toWord8 <$> ColorRGB 1 (0.5 :: Double) 0
showColorRGB c

-- %%
:t showColorRGB
-- Out:
-- showColorRGB :: Color RGB Word8 -> IO Display

-- %%
:t makeArrayR
display $ makeArrayR S Seq (Sz2 255 255) $ \(i :. j) -> ColorRGB 0 (fromIntegral i) (fromIntegral j) :: Color RGB Word8
-- Out:
-- makeArrayR :: forall r ix e. Construct r ix e => r -> Comp -> Sz ix -> (ix -> e) -> Array r ix e

-- %%
hsl = ColorHSL 0.3798 1 0.2745
ColorH360SL h360 _ _ = hsl
h360
ColorH360SL 136.728 1 0.2745
cmyk2rgb $ ColorCMYK 1 2 3 5
:t ColorHSL
:t ColorH360SL
-- Out:
-- 136.728
-- <HSL:( 0.379800000000, 1.000000000000, 0.274500000000)>
-- <RGB:(-0.000000000000, 1.000000000000, 1.000000000000)>
-- ColorHSL :: forall e. e -> e -> e -> Color HSL e
-- ColorH360SL :: forall e. Fractional e => e -> e -> e -> Color HSL e

-- %%
showColorRGB (toWord8 <$> hsl2rgb hsl) -- RAL Pure Green HSL (sRGB) adopted

-- %%
wrongColor = ColorRGB 0x25 0xE7 0x12 :: Color RGB Word8 -- RAL Pure Green HSL (sRGB) wrong
wrongColor
showColorRGB wrongColor
-- Out:
-- <RGB:( 37,231, 18)>
